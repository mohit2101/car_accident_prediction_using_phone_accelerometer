# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv('/home/mohit/Downloads/PHONE FALL DATA FILE.csv')
data2 = pd.read_csv('/home/mohit/Downloads/ACCIDENTAL DATA FILE.csv')

# %%
data1
# Out:
#       ACTUAL TIME (ms)  TIME INTERVAL (ms)         X         Y
# 0                    0                   0 -3.237152  2.039383
# 1                    8                   8 -3.347595  1.998138
# 2                   12                   4 -3.489105  1.942612
# 3                   15                   3 -3.608948  1.878632
# 4                   23                   8 -3.689438  1.838272
# 5                   27                   4 -3.664169  1.849396
# 6                   31                   4 -3.622330  1.933884
# 7                   35                   4 -3.546753  2.096161
# 8                   43                   8 -3.435577  2.352158
# 9                   47                   4 -3.391312  2.372589
# 10                  51                   4 -3.438278  2.285385
# 11                  58                   7 -3.457855  2.280609
# 12                  62                   4 -3.383621  2.438354
# 13                  71                   9 -3.290634  2.655731
# ...

# %%
data2
# Out:
#       MS     X     Y
# 0      2  -9.8   2.2
# 1      4  -7.8   0.2
# 2      6  -7.8   1.8
# 3      8  -5.8   2.6
# 4     10  -4.6   1.0
# 5     12 -13.4   0.2
# 6     14 -11.0   3.4
# 7     16  -6.2  -5.0
# 8     18  -3.8  -0.2
# 9     20  -1.8   3.8
# 10    22  -9.0   3.8
# 11    24  -3.8   3.4
# 12    26  -5.8   0.2
# 13    28  -3.0  -0.2
# 14    30  -6.6  -0.2
# 15    32  -3.8   1.4
# 16    34 -11.4  -1.0
# 17    36  -5.8   3.4
# 18    38 -17.8  -1.0
# 19    40 -12.2   4.2
# 20    42 -13.0  -1.0
# 21    44  -9.0   2.6
# 22    46  -8.2   0.2
# 23    48 -11.0   2.6
# 24    50 -12.6  -3.8
# 25    52 -12.2  -2.6
# 26    54 -13.8  -6.2
# 27    56 -15.4  -5.4
# 28    58 -11.8  -6.2
# 29    60 -13.4  -5.4
# ..   ...   ...   ...
# 146  294  -0.2  -0.2
# 147  296  -0.2  -0.2
# 148  298  -0.2  -0.2
# 149  300  -0.2  -0.2
# 150    0   0.0   0.0
# 151   10   0.0   4.5
# 152   20   1.5  17.5
# 153   30   5.5  44.0
# 154   40  -7.0  20.0
# 155   50  -4.0  16.5
# 156   60   0.0  -7.0
# ...

# %%
data1 = data1.assign(response = '0')
data2 = data2.assign(response = '1')

# %%
data1
# Out:
#       ACTUAL TIME (ms)  TIME INTERVAL (ms)         X         Y response
# 0                    0                   0 -3.237152  2.039383        0
# 1                    8                   8 -3.347595  1.998138        0
# 2                   12                   4 -3.489105  1.942612        0
# 3                   15                   3 -3.608948  1.878632        0
# 4                   23                   8 -3.689438  1.838272        0
# 5                   27                   4 -3.664169  1.849396        0
# 6                   31                   4 -3.622330  1.933884        0
# 7                   35                   4 -3.546753  2.096161        0
# 8                   43                   8 -3.435577  2.352158        0
# 9                   47                   4 -3.391312  2.372589        0
# 10                  51                   4 -3.438278  2.285385        0
# 11                  58                   7 -3.457855  2.280609        0
# ...

# %%
data2
# Out:
#       MS     X     Y response
# 0      2  -9.8   2.2        1
# 1      4  -7.8   0.2        1
# 2      6  -7.8   1.8        1
# 3      8  -5.8   2.6        1
# 4     10  -4.6   1.0        1
# 5     12 -13.4   0.2        1
# 6     14 -11.0   3.4        1
# 7     16  -6.2  -5.0        1
# 8     18  -3.8  -0.2        1
# 9     20  -1.8   3.8        1
# 10    22  -9.0   3.8        1
# 11    24  -3.8   3.4        1
# 12    26  -5.8   0.2        1
# 13    28  -3.0  -0.2        1
# 14    30  -6.6  -0.2        1
# 15    32  -3.8   1.4        1
# 16    34 -11.4  -1.0        1
# 17    36  -5.8   3.4        1
# 18    38 -17.8  -1.0        1
# 19    40 -12.2   4.2        1
# 20    42 -13.0  -1.0        1
# 21    44  -9.0   2.6        1
# 22    46  -8.2   0.2        1
# 23    48 -11.0   2.6        1
# 24    50 -12.6  -3.8        1
# 25    52 -12.2  -2.6        1
# 26    54 -13.8  -6.2        1
# 27    56 -15.4  -5.4        1
# 28    58 -11.8  -6.2        1
# 29    60 -13.4  -5.4        1
# ...

# %%
data1 = data1.iloc[:, 2:]
data2 = data2.iloc[:, 1:]
data = pd.concat([data1, data2],ignore_index = True)

# %%
data
# Out:
#              X          Y response
# 0    -3.237152   2.039383        0
# 1    -3.347595   1.998138        0
# 2    -3.489105   1.942612        0
# 3    -3.608948   1.878632        0
# 4    -3.689438   1.838272        0
# 5    -3.664169   1.849396        0
# 6    -3.622330   1.933884        0
# 7    -3.546753   2.096161        0
# 8    -3.435577   2.352158        0
# 9    -3.391312   2.372589        0
# 10   -3.438278   2.285385        0
# 11   -3.457855   2.280609        0
# 12   -3.383621   2.438354        0
# 13   -3.290634   2.655731        0
# 14   -3.239853   2.845398        0
# 15   -3.239792   2.932816        0
# 16   -3.342392   2.889160        0
# 17   -3.560379   2.678635        0
# 18   -3.917511   2.383743        0
# 19   -4.186707   2.037994        0
# 20   -4.367203   1.727860        0
# 21   -4.468063   1.511200        0
# 22   -4.497253   1.420105        0
# 23   -4.515839   1.458603        0
# 24   -4.522842   1.616287        0
# 25   -4.495178   1.865051        0
# ...

# %%
from sklearn.utils import shuffle
data = shuffle(data)
#data = data.sample(frac = 1).reset_index(drop = True)

# %%
data
# Out:
#               X         Y response
# 1643   0.426147  4.323898        0
# 27    -4.396011  2.432922        0
# 1724   0.548019  4.484390        0
# 2561  -0.200000  0.200000        1
# 2668   0.000000 -1.500000        1
# 2346   0.450516  4.402679        0
# 1069   0.205078  5.055054        0
# 614   -0.419189  4.799896        0
# 735   -0.376236  4.814117        0
# 860    0.178146  5.156632        0
# 72    -3.127106  2.553986        0
# 662   -0.368332  4.777206        0
# 227   -0.911346  4.408295        0
# 188   -2.512161  3.580399        0
# 1569   0.751968  3.248947        0
# 2401   0.609100  4.494263        0
# 759   -0.400024  4.815262        0
# 1166   0.280807  5.015152        0
# 671   -0.450302  4.801788        0
# 2645  -0.200000 -0.200000        1
# 2473   0.540649  4.485626        0
# 2600  -0.200000 -0.200000        1
# 2312   0.457489  4.317444        0
# 177   -2.304779  3.224289        0
# 2122   0.617233  4.531754        0
# 884    0.125320  5.090241        0
# ...

# %%
from sklearn.model_selection import train_test_split
x = data.drop('response', axis = 1)
y = data['response']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)
clf = clf.fit(x_train, y_train)
# Out:
# /usr/lib/python3/dist-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
print(accuracy_score(y_test, pred))
# Out:
# 0.9887920298879203

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[739   2]
#  [  7  55]]

# %%
print(classification_report(y_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99       741
#           1       0.96      0.89      0.92        62
#
# avg / total       0.99      0.99      0.99       803

# %%
print(clf.predict([[-2.0,-3.0]]))
# Out:
# ['1']
